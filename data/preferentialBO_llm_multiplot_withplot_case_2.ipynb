# %%
#change utility2 by the corresponding number, get back utility 3   done
#change prompt  done 
#change pickle filename done
#change plot name done
#change objective name done

# %%
import os
import warnings
from itertools import combinations

import numpy as np
import torch
import time

# Suppress potential optimization warnings for cleaner notebook
warnings.filterwarnings("ignore")

SMOKE_TEST = os.environ.get("SMOKE_TEST")

# %%
import DTLZ2_model
import fischer_model
from botorch.test_functions.multi_objective import DTLZ2
from DTLZ2_model import neg_l1_dist
from DTLZ2_model import predict_DTLZ2_model
from fischer_model import predict_fischer_model
import tensorflow as tf
import random


from botorch.fit import fit_gpytorch_mll 
from botorch.models.pairwise_gp import PairwiseGP, PairwiseLaplaceMarginalLogLikelihood 
from botorch.models.transforms.input import Normalize
import pickle

# %%
 #Your chosen seed
your_seed = 42

# Set seed for Python's RNG
random.seed(your_seed)

# Set seed for NumPy RNG
np.random.seed(your_seed)

# Set seed for PyTorch RNGs
torch.manual_seed(your_seed)

# Ensure reproducibility for PyTorch operations (might reduce performance)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# If using CUDA (PyTorch)
torch.cuda.manual_seed(your_seed)
torch.cuda.manual_seed_all(your_seed)  # For multi-GPU setups

# %%
predict_fischer_model(torch.tensor([[0.5, 0.5, 0.5, 0.5]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# tensor([[0.6455, 0.0591, 0.1161, 0.5071]])

# %%
import cohere
co = cohere.Client('9ylnov4iFULBLovujZIJLq6x8pkq4NkyNCw0oePR')

# %%
# data generating helper functions
#function that defines the comparisons
def utility(X):
    y=predict_fischer_model(X)
    #weighted_y = y * torch.sqrt(torch.arange(y.size(-1), dtype=torch.float) + 1)
    #y = torch.sum(weighted_y, dim=-1)
    return y

def utility1(X): #The four outputs are equally important, and we want to maximize all of them.
    y=predict_fischer_model(X)
    y = torch.sum(y, dim=-1)
    return y

def utility2(X): #We only want to maximize the CO conversion.
    y=predict_fischer_model(X)
    y = y[:,0]
    return y

def utility3(X): # The light olefins is considered as a negative output and we want to minimize it while maximizing the other three objectives.
    y=predict_fischer_model(X)
    y = y[:,0]+y[:,1]+y[:,2]-y[:,3]
    return y
    
def ini(n,dim):
    X = torch.rand(n, dim, dtype=torch.float64)
    return X
def generate_data(X, dim=4):
    """Generate data X and y"""
    # X is randomly sampled from dim-dimentional unit cube
    # we recommend using double as opposed to float tensor here for
    # better numerical stability
    #X=ini(n,dim)
    x_2=tf.convert_to_tensor(X, dtype=tf.float32)
    y = utility(x_2)
    return y

def generate_data_u1(X, dim=4):
    """Generate data X and y"""
    # X is randomly sampled from dim-dimentional unit cube
    # we recommend using double as opposed to float tensor here for
    # better numerical stability
    #X=ini(n,dim)
    x_2=tf.convert_to_tensor(X, dtype=tf.float32)
    y = utility2(x_2)
    return y

# %%
def generate_comparisons(y, n_comp, noise=0.1, replace=False):
    """Create pairwise comparisons with noise"""
    # generate all possible pairs of elements in y
    all_pairs = np.array(list(combinations(range(y.shape[0]), 2)))
    # randomly select n_comp pairs from all_pairs
    comp_pairs = all_pairs[
        np.random.choice(range(len(all_pairs)), n_comp, replace=replace)
    ]
    # add gaussian noise to the latent y values
    c0 = y[comp_pairs[:, 0]] + np.random.standard_normal(len(comp_pairs)) * noise
    c1 = y[comp_pairs[:, 1]] + np.random.standard_normal(len(comp_pairs)) * noise
    reverse_comp = (c0 < c1).numpy()
    comp_pairs[reverse_comp, :] = np.flip(comp_pairs[reverse_comp, :], 1)
    comp_pairs = torch.tensor(comp_pairs).long()

    return comp_pairs

# %%
#im not sure if this is is the correct function, i'm a bit eepy
#remember to reduce the number of comparisons n_comp,
def generate_comparisons_llm(y, n_comp, replace=False):
    """Create pairwise comparisons with noise"""
    # generate all possible pairs of elements in y
    all_pairs = np.array(list(combinations(range(y.shape[0]), 2)))
    # randomly select n_comp pairs from all_pairs
    comp_pairs = all_pairs[
        np.random.choice(range(len(all_pairs)), n_comp, replace=replace)
    ]
    #parsing the tensor to get the strings for the LLM
    new_pairs=[]
    for opto in comp_pairs:
        firstoption=opto[0]
        secondoption=opto[1]
        numfirst=(y[firstoption,:])
        firstoutput1=f"{numfirst[0].cpu().numpy():.1f}"
        firstoutput2=f"{numfirst[1].cpu().numpy():.1f}"
        firstoutput3=f"{numfirst[2].cpu().numpy():.1f}"
        firstoutput4=f"{numfirst[3].cpu().numpy():.1f}"
        numsecond=(y[secondoption,:])
        secondoutput1=f"{numsecond[0].cpu().numpy():.1f}"
        secondoutput2=f"{numsecond[1].cpu().numpy():.1f}"
        secondoutput3=f"{numsecond[2].cpu().numpy():.1f}"
        secondoutput4=f"{numsecond[3].cpu().numpy():.1f}"
        mess="Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of "+firstoutput1+" CO conversion, "+firstoutput2+" methane, "+firstoutput3+" paraffin, "+firstoutput4+" light olefins. Option B: regime of "+secondoutput1+" CO conversion, "+secondoutput2+" methane, "+secondoutput3+" paraffins, "+secondoutput4+" light olefins. Choose only one option, only answer with 'Option A' or 'Option B'"
        print(mess)
        response = co.chat(message=mess,
        #perform web search before answering the question. You can also use your own custom connector.
                          #connectors=[{"id": "web-search"}]
        )
        print(response.text)
        opllm=response.text
        
        if "Option A" in opllm:
            new_pairs.append(opto.tolist())
        else:
            new_pairs.append(list(reversed(opto)))
        #api restrictions 20 API calls/minutes
        time.sleep(6)
    
    return torch.tensor(new_pairs)

#"Suppose you're managing a Fischer-Tropsch synthesis process. The four outputs are equally important, and we want to maximize all of them. Option A: regime of "+firstoutput1+" CO conversion, "+firstoutput2+" methane production, "+firstoutput3+" paraffins, "+firstoutput4+" light olefins. Option B: regime of "+secondoutput1+" CO conversion, "+secondoutput2+" methane production, "+secondoutput3+" paraffins, "+secondoutput4+" light olefins. Choose only one option, only answer with 'Option A' or 'Option B'"
#"Suppose you're managing a Fischer-Tropsch synthesis process. The light olefins are considered as a negative output and we want to minimize them, while maximizing the other three outputs. Option A: regime of "+firstoutput1+" CO conversion, "+firstoutput2+" methane, "+firstoutput3+" paraffin, "+firstoutput4+" light olefins. Option B: regime of "+secondoutput1+" CO conversion, "+secondoutput2+" methane, "+secondoutput3+" paraffins, "+secondoutput4+" light olefins. Choose only one option, only answer with 'Option A' or 'Option B'"
#"Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of "+firstoutput1+" CO conversion, "+firstoutput2+" methane, "+firstoutput3+" paraffin, "+firstoutput4+" light olefins. Option B: regime of "+secondoutput1+" CO conversion, "+secondoutput2+" methane, "+secondoutput3+" paraffins, "+secondoutput4+" light olefins. Choose only one option, only answer with 'Option A' or 'Option B'"

# %% [markdown]
# #parameters
# torch.manual_seed(123)
# #number for initial data
# n = 5 if not SMOKE_TEST else 5
# #number for initial comparisons
# m = 10 if not SMOKE_TEST else 10
# dim = 4
# noise = 0.1
#
# #generate data, initial data
# train_X, train_y = generate_data(n, dim=dim)
# #generating comparison based on the utility function

# %% [markdown]
# train_comp_llm = generate_comparisons_llm(train_y, m)

# %% [markdown]
# train_comp_llm

# %% [markdown]
# from botorch.fit import fit_gpytorch_mll
# from botorch.models.pairwise_gp import PairwiseGP, PairwiseLaplaceMarginalLogLikelihood
# from botorch.models.transforms.input import Normalize
#
# #fitting the first pairwise GP
# model = PairwiseGP(
#     train_X,
#     train_comp_llm,
#     input_transform=Normalize(d=train_X.shape[-1]),
# )
# mll = PairwiseLaplaceMarginalLogLikelihood(model.likelihood, model)
# mll = fit_gpytorch_mll(mll)

# %% [markdown]
# from scipy.stats import kendalltau
#
#
# # Kendall-Tau rank correlation
# def eval_kt_cor(model, test_X, test_y):
#     pred_y = model.posterior(test_X).mean.squeeze().detach().numpy()
#     return kendalltau(pred_y, test_y).correlation
#
#
# n_kendall = 10 if not SMOKE_TEST else 10
#
# test_X, test_y = generate_data(n_kendall, dim=dim)
# kt_correlation = eval_kt_cor(model, test_X, test_y[:,3])
#
# print(f"Test Kendall-Tau rank correlation: {kt_correlation:.4f}")

# %%
from botorch.acquisition.preference import AnalyticExpectedUtilityOfBestOption
from botorch.optim import optimize_acqf

#wrapper for the model
def init_and_fit_model(X, comp):
    """Model fitting helper function"""
    model = PairwiseGP(
        X,
        comp,
        input_transform=Normalize(d=X.shape[-1]),
    )
    mll = PairwiseLaplaceMarginalLogLikelihood(model.likelihood, model)
    fit_gpytorch_mll(mll)
    return mll, model

#wrapper for making new data, what does it mean? return comps

def make_new_data(X, next_X, comps, q_comp):
    """Given X and next_X,
    generate q_comp new comparisons between next_X
    and return the concatenated X and comparisons
    """
    # next_X is float by default; cast it to the dtype of X (i.e., double)
    next_X = next_X.to(X)
    x_2=tf.convert_to_tensor(next_X, dtype=tf.float32)
    next_y = utility(x_2)
    next_comps = generate_comparisons_llm(next_y, n_comp=q_comp)
    comps = torch.cat([comps, next_comps + X.shape[-2]])
    X = torch.cat([X, next_X])
    return X, comps

def make_new_data_u1(X, next_X, comps, q_comp):
    """Given X and next_X,
    generate q_comp new comparisons between next_X
    and return the concatenated X and comparisons
    """
    # next_X is float by default; cast it to the dtype of X (i.e., double)
    next_X = next_X.to(X)
    x_2=tf.convert_to_tensor(next_X, dtype=tf.float32)
    next_y = utility2(x_2)
    next_comps = generate_comparisons(next_y, n_comp=q_comp)
    comps = torch.cat([comps, next_comps + X.shape[-2]])
    X = torch.cat([X, next_X])
    return X, comps

# %%
#two algorithms to compare
algos = ["EUBO","EUBO-LLM", "rand"]
#number of repetitions of the BO cycle
NUM_TRIALS = 3 if not SMOKE_TEST else 2
#number of cycles
NUM_BATCHES = 20 if not SMOKE_TEST else 2

#dimension number= 4 inputs
dim = 4
#sampler options
NUM_RESTARTS = 3
RAW_SAMPLES = 512 if not SMOKE_TEST else 8
#
q_eubo = 2  # number of points per query
q_data=5
q_comp = 10  # number of comparisons per query
q_comp_2=1

# initial evals
best_vals = {}  # best observed values
for algo in algos:
    best_vals[algo] = []

# average over multiple trials
for i in range(NUM_TRIALS):
    torch.manual_seed(i)
    np.random.seed(i)
    data = {}
    models = {}

     # X are within the unit cube
    bounds = torch.stack([torch.zeros(dim), torch.ones(dim)])

    # Create initial data
    init_X=ini(q_data,dim)
    for algo in algos:
        if algo == "EUBO-LLM":
            init_y = generate_data(init_X, dim=dim)
            comparisons = generate_comparisons_llm(init_y, q_comp)
        if algo == "EUBO":
            init_y = generate_data_u1(init_X, dim=dim)
            comparisons = generate_comparisons(init_y, q_comp)
        if algo == "rand":
            init_y = generate_data_u1(init_X, dim=dim)
            comparisons = generate_comparisons(init_y, q_comp)
   
        best_vals[algo].append([])
        data[algo] = (init_X, comparisons)
        _, models[algo] = init_and_fit_model(init_X, comparisons)

        best_next_y = utility2(init_X).max().item()
        best_vals[algo][-1].append(best_next_y)

    # we make additional NUM_BATCHES comparison queries after the initial observation
    for j in range(1, NUM_BATCHES + 1):
        print(j)
        for algo in algos:
            model = models[algo]
            if algo == "EUBO-LLM":
                # create the acquisition function object
                acq_func = AnalyticExpectedUtilityOfBestOption(pref_model=model)
                # optimize and get new observation
                next_X, acq_val = optimize_acqf(
                    acq_function=acq_func,
                    bounds=bounds,
                    q=q_eubo,
                    num_restarts=NUM_RESTARTS,
                    raw_samples=RAW_SAMPLES,
                )
                print(next_X)
                # update data
                X, comps = data[algo]
                X, comps = make_new_data(X, next_X, comps, q_comp_2)
                data[algo] = (X, comps)
    
                # refit models
                _, models[algo] = init_and_fit_model(X, comps)
    
                # record the best observed values so far
                max_val = utility2(X).max().item()
                best_vals[algo][-1].append(max_val)
            elif algo == "EUBO":
                 #create the acquisition function object
                acq_func = AnalyticExpectedUtilityOfBestOption(pref_model=model)
                # optimize and get new observation
                next_X, acq_val = optimize_acqf(
                    acq_function=acq_func,
                    bounds=bounds,
                    q=q_eubo,
                    num_restarts=NUM_RESTARTS,
                    raw_samples=RAW_SAMPLES,
                )
                print(next_X)
                # update data
                X, comps = data[algo]
                X, comps = make_new_data_u1(X, next_X, comps, q_comp_2)
                data[algo] = (X, comps)
    
                # refit models
                _, models[algo] = init_and_fit_model(X, comps)
    
                # record the best observed values so far
                max_val = utility2(X).max().item()
                best_vals[algo][-1].append(max_val)
            else:
                # randomly sample data
                next_X= ini(q_eubo, dim=dim)
                print(next_X)
                # update data
                X, comps = data[algo]
                X, comps = make_new_data_u1(X, next_X, comps, q_comp_2)
                data[algo] = (X, comps)
    
                # refit models
                _, models[algo] = init_and_fit_model(X, comps)
    
                # record the best observed values so far
                max_val = utility2(X).max().item()
                best_vals[algo][-1].append(max_val)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffin, 0.2 light olefins. Option B: regime of 0.6 CO conversion, 0.0 methane, 0.1 paraffins, 0.5 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.7 CO conversion, 0.1 methane, 0.2 paraffin, 0.4 light olefins. Option B: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffins, 0.2 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffin, 0.2 light olefins. Option B: regime of 0.5 CO conversion, 0.0 methane, 0.1 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.7 CO conversion, 0.1 methane, 0.2 paraffin, 0.4 light olefins. Option B: regime of 0.6 CO conversion, 0.0 methane, 0.1 paraffins, 0.5 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.7 CO conversion, 0.1 methane, 0.2 paraffin, 0.4 light olefins. Option B: regime of 0.8 CO conversion, 0.1 methane, 0.2 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffin, 0.2 light olefins. Option B: regime of 0.8 CO conversion, 0.1 methane, 0.2 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.5 CO conversion, 0.0 methane, 0.1 paraffin, 0.6 light olefins. Option B: regime of 0.6 CO conversion, 0.0 methane, 0.1 paraffins, 0.5 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.6 CO conversion, 0.0 methane, 0.1 paraffin, 0.5 light olefins. Option B: regime of 0.8 CO conversion, 0.1 methane, 0.2 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.7 CO conversion, 0.1 methane, 0.2 paraffin, 0.4 light olefins. Option B: regime of 0.5 CO conversion, 0.0 methane, 0.1 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.5 CO conversion, 0.0 methane, 0.1 paraffin, 0.6 light olefins. Option B: regime of 0.8 CO conversion, 0.1 methane, 0.2 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1
# tensor([[0.1445, 0.0686, 0.7034, 0.7427],
#         [0.5976, 0.3396, 0.6566, 0.8899]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.5976, 0.3397, 0.6566, 0.8899],
#         [0.1445, 0.0686, 0.7034, 0.7427]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.1 methane, 0.3 paraffin, 0.6 light olefins. Option B: regime of 0.8 CO conversion, 0.1 methane, 0.2 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.9993, 0.4076, 0.8184, 0.6327],
#         [0.9654, 0.2146, 0.1355, 0.1397]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2
# tensor([[0.6244, 0.5012, 0.7934, 0.8150],
#         [0.5737, 0.1792, 0.5370, 0.9840]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.5736, 0.1793, 0.5370, 0.9841],
#         [0.6245, 0.5011, 0.7934, 0.8150]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.7 CO conversion, 0.1 methane, 0.2 paraffin, 0.5 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.5 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.8229, 0.6363, 0.8937, 0.7821],
#         [0.7483, 0.7476, 0.7821, 0.1637]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3
# tensor([[0.4208, 0.6382, 0.7615, 0.9418],
#         [0.8140, 0.2977, 0.8082, 0.7551]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.8140, 0.2976, 0.8082, 0.7552],
#         [0.4209, 0.6382, 0.7616, 0.9417]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.5 paraffin, 0.7 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.4 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0369, 0.9699, 0.0239, 0.1649],
#         [0.6935, 0.5776, 0.9434, 0.5718]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4
# tensor([[0.4934, 0.5365, 0.7156, 0.9625],
#         [0.3684, 0.8457, 0.9557, 0.8115]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.7168, 0.3870, 0.7247, 0.7132],
#         [0.8596, 0.2305, 0.9516, 0.8996]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.2 methane, 0.4 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.4 methane, 0.8 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.6556, 0.5996, 0.0901, 0.0419],
#         [0.5903, 0.6976, 0.3918, 0.9083]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 5
# tensor([[0.4446, 0.6159, 0.6559, 0.8883],
#         [0.5312, 0.4541, 0.8500, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[1.0000, 0.0342, 0.8872, 1.0000],
#         [0.7806, 0.3975, 1.0000, 0.7908]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.7 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.6 methane, 0.8 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.2189, 0.6521, 0.7849, 0.1830],
#         [0.6764, 0.5461, 0.4708, 0.7864]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 6
# tensor([[0.3021, 0.3816, 0.9409, 1.0000],
#         [0.6298, 0.5484, 0.8082, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[1.0000, 0.0000, 1.0000, 0.8487],
#         [0.9741, 0.2398, 0.8268, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.4 methane, 0.8 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.9264, 0.5024, 0.5329, 0.6124],
#         [0.2229, 0.9591, 0.3407, 0.9507]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7
# tensor([[0.0609, 0.4695, 0.8219, 1.0000],
#         [0.4534, 0.4013, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.8899, 0.0000, 0.8137, 1.0000],
#         [1.0000, 0.4148, 0.8748, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.2 methane, 0.5 paraffin, 0.6 light olefins. Option B: regime of 1.0 CO conversion, 0.4 methane, 0.7 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.2818, 0.3571, 0.6197, 0.9133],
#         [0.6336, 0.1661, 0.5592, 0.4178]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8
# tensor([[0.0000, 0.4824, 1.0000, 1.0000],
#         [0.1855, 0.4305, 0.7365, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.6609, 0.0241, 0.8856, 1.0000],
#         [1.0000, 0.0000, 0.7851, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.2 methane, 0.5 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.6381, 0.0582, 0.6272, 0.5508],
#         [0.2384, 0.2421, 0.5874, 0.6377]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9
# tensor([[0.2022, 0.4382, 0.7715, 1.0000],
#         [0.0000, 0.4240, 0.8710, 0.7360]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[1.0000, 0.0192, 0.8679, 1.0000],
#         [1.0000, 0.0000, 0.7113, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 0.9 CO conversion, 0.1 methane, 0.4 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.4436, 0.6882, 0.3639, 0.6899],
#         [0.1404, 0.3417, 0.1760, 0.8757]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 10
# tensor([[0.0000, 0.4786, 0.7033, 1.0000],
#         [0.3383, 0.4116, 0.8122, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[1.0000, 0.0115, 0.8380, 1.0000],
#         [1.0000, 1.0000, 1.0000, 0.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.6 light olefins. Option B: regime of 0.6 CO conversion, 0.9 methane, 0.1 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.8598, 0.9765, 0.8934, 0.3508],
#         [0.0936, 0.5892, 0.3021, 0.1378]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 11
# tensor([[0.0060, 0.4515, 0.7816, 1.0000],
#         [0.0000, 0.4584, 0.4799, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[1.0000, 0.0000, 0.8378, 1.0000],
#         [0.0000, 1.0000, 1.0000, 0.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.6 light olefins. Option B: regime of 0.5 CO conversion, 0.7 methane, 0.1 paraffins, 0.9 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.4807, 0.0293, 0.4207, 0.9270],
#         [0.2794, 0.7251, 0.7783, 0.0429]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 12
# tensor([[0.0000, 0.4577, 0.7644, 1.0000],
#         [1.0000, 1.0000, 1.0000, 0.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0000, 1.0000, 1.0000, 0.0000],
#         [1.0000, 0.0000, 0.8373, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.5 CO conversion, 0.7 methane, 0.1 paraffin, 0.9 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.4150, 0.7800, 0.7569, 0.1597],
#         [0.9317, 0.5596, 0.6973, 0.3404]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 13
# tensor([[0.0000, 0.6322, 0.7581, 1.0000],
#         [0.0000, 0.3620, 0.7745, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[1.0000, 1.0000, 1.0000, 0.0000],
#         [1.0000, 0.0000, 0.8371, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.6 CO conversion, 0.9 methane, 0.1 paraffin, 0.8 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.9379, 0.8532, 0.0673, 0.9188],
#         [0.5133, 0.5673, 0.0362, 0.9549]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 14
# tensor([[0.0000, 0.9366, 0.7164, 1.0000],
#         [0.0102, 0.5151, 0.7697, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step
# tensor([[1.0000, 0.0000, 0.8386, 1.0000],
#         [0.0000, 1.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.6 light olefins. Option B: regime of 1.0 CO conversion, 0.5 methane, 0.6 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# tensor([[0.9052, 0.9408, 0.3937, 0.0563],
#         [0.9709, 0.5686, 0.8613, 0.0944]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 15
# tensor([[0.0000, 0.5376, 0.7651, 1.0000],
#         [0.0000, 1.0000, 1.0000, 0.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# tensor([[0.0000, 1.0000, 1.0000, 1.0000],
#         [1.0000, 0.1416, 0.8532, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.5 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# tensor([[0.8025, 0.4828, 0.3019, 0.0524],
#         [0.5473, 0.5828, 0.2354, 0.7081]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 16
# tensor([[0.0000, 0.5360, 0.7649, 1.0000],
#         [1.0000, 0.0000, 0.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# tensor([[1.0000, 0.0000, 0.7994, 1.0000],
#         [0.7846, 0.5329, 0.9317, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.2 methane, 0.5 paraffin, 0.6 light olefins. Option B: regime of 1.0 CO conversion, 0.5 methane, 0.8 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step
# tensor([[0.6943, 0.5448, 0.4108, 0.3333],
#         [0.8161, 0.8785, 0.9122, 0.7378]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
# 17
# tensor([[0.3315, 0.4753, 0.7913, 1.0000],
#         [0.0000, 0.5553, 0.7580, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# tensor([[0.5852, 0.3086, 0.8027, 1.0000],
#         [1.0000, 0.0000, 0.8260, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.5 paraffin, 0.6 light olefins. Option B: regime of 1.0 CO conversion, 0.2 methane, 0.5 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# tensor([[0.2582, 0.0738, 0.6904, 0.6015],
#         [0.9862, 0.0688, 0.7787, 0.4235]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 18
# tensor([[0.3802, 0.4831, 0.7821, 1.0000],
#         [0.0000, 0.5239, 0.7696, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# tensor([[1.0000, 0.0000, 0.8372, 1.0000],
#         [1.0000, 0.0000, 0.8200, 0.6746]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.6 light olefins. Option B: regime of 0.9 CO conversion, 0.2 methane, 0.5 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# tensor([[0.7413, 0.0618, 0.1426, 0.4657],
#         [0.0988, 0.9242, 0.8471, 0.0830]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 19
# tensor([[0.1327, 0.5384, 0.7878, 1.0000],
#         [0.4512, 0.4380, 0.7671, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step
# tensor([[1.0000, 0.0000, 0.8388, 1.0000],
#         [1.0000, 0.0000, 1.0000, 0.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.6 light olefins. Option B: regime of 0.6 CO conversion, 0.6 methane, 0.1 paraffins, 0.9 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# tensor([[0.6741, 0.2367, 0.0333, 0.6234],
#         [0.3189, 0.5169, 0.1927, 0.5772]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 20
# tensor([[0.2590, 0.5093, 0.7764, 1.0000],
#         [0.5951, 0.3733, 0.7688, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# tensor([[0.0000, 1.0000, 1.0000, 1.0000],
#         [1.0000, 0.0000, 0.8413, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.5 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# tensor([[0.4508, 0.0915, 0.9085, 0.0185],
#         [0.9158, 0.0230, 0.1545, 0.4304]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffin, 0.6 light olefins. Option B: regime of 0.1 CO conversion, 0.0 methane, 0.0 paraffins, 0.1 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.1 CO conversion, 0.0 methane, 0.0 paraffin, 0.1 light olefins. Option B: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffins, 0.5 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffin, 0.6 light olefins. Option B: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffins, 0.5 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.6 CO conversion, 0.0 methane, 0.1 paraffin, 0.4 light olefins. Option B: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffins, 0.5 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffin, 0.2 light olefins. Option B: regime of 0.1 CO conversion, 0.0 methane, 0.0 paraffins, 0.1 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffin, 0.2 light olefins. Option B: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffin, 0.2 light olefins. Option B: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffins, 0.5 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.6 CO conversion, 0.0 methane, 0.1 paraffin, 0.4 light olefins. Option B: regime of 0.1 CO conversion, 0.0 methane, 0.0 paraffins, 0.1 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffin, 0.2 light olefins. Option B: regime of 0.6 CO conversion, 0.0 methane, 0.1 paraffins, 0.4 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.6 CO conversion, 0.0 methane, 0.1 paraffin, 0.4 light olefins. Option B: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1
# tensor([[0.6980, 0.3222, 0.5587, 0.6502],
#         [0.3841, 0.7452, 0.6149, 0.0012]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.7033, 0.3848, 0.5780, 0.2386],
#         [0.5154, 0.5570, 0.5009, 0.5655]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffin, 0.7 light olefins. Option B: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffins, 0.5 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.4825, 0.0699, 0.1585, 0.4023],
#         [0.7195, 0.1778, 0.1376, 0.8300]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2
# tensor([[0.8097, 0.2123, 0.6235, 0.5004],
#         [0.6591, 0.4558, 0.5452, 0.8689]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.4631, 0.3846, 0.6107, 0.2122],
#         [0.9022, 0.4351, 0.5474, 0.3320]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffin, 0.7 light olefins. Option B: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffins, 0.6 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.1596, 0.9781, 0.2918, 0.6598],
#         [0.1089, 0.2881, 0.4296, 0.8830]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3
# tensor([[0.8713, 0.4431, 0.4962, 0.8715],
#         [0.4855, 0.4071, 0.6094, 0.8545]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.4789, 0.3209, 0.6237, 0.3194],
#         [0.4374, 0.5466, 0.6122, 0.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.8 CO conversion, 0.1 methane, 0.2 paraffin, 0.7 light olefins. Option B: regime of 0.5 CO conversion, 0.1 methane, 0.1 paraffins, 0.9 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.9907, 0.0485, 0.5132, 0.0123],
#         [0.8930, 0.6538, 0.1286, 0.2497]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4
# tensor([[0.6245, 0.4141, 0.6882, 0.9858],
#         [0.4081, 0.4250, 0.5364, 0.7577]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.4543, 0.3221, 0.5515, 0.2351],
#         [0.5316, 0.3718, 0.7294, 0.3567]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.7 CO conversion, 0.1 methane, 0.1 paraffin, 0.7 light olefins. Option B: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.9017, 0.6875, 0.2295, 0.9151],
#         [0.6118, 0.4312, 0.0155, 0.7727]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5
# tensor([[0.6329, 0.2544, 0.6514, 0.5419],
#         [0.6323, 0.4772, 0.5491, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.6619, 0.2365, 0.8053, 0.1621],
#         [0.4450, 0.4093, 0.7075, 0.4004]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.8 CO conversion, 0.3 methane, 0.2 paraffin, 0.9 light olefins. Option B: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.5980, 0.8285, 0.8187, 0.4079],
#         [0.5471, 0.7395, 0.8349, 0.5343]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 6
# tensor([[0.0000, 1.0000, 1.0000, 1.0000],
#         [0.6361, 0.2796, 0.6388, 0.5927]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.5937, 0.4045, 0.6924, 0.3718],
#         [0.1363, 0.3665, 0.7758, 0.3959]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffin, 0.7 light olefins. Option B: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.7115, 0.9177, 0.8786, 0.0093],
#         [0.4481, 0.6070, 0.8597, 0.5625]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7
# tensor([[0.5652, 0.8834, 0.9105, 0.8989],
#         [0.0366, 0.4157, 0.9303, 0.9927]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.2176, 0.3644, 0.9047, 0.5822],
#         [0.1384, 0.3838, 0.7262, 0.3222]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.4 methane, 0.4 paraffin, 0.8 light olefins. Option B: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.5528, 0.2100, 0.0321, 0.7415],
#         [0.0828, 0.5402, 0.7208, 0.4698]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8
# tensor([[0.2953, 1.0000, 0.8226, 0.9351],
#         [0.7035, 0.6419, 1.0000, 0.8745]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.3372, 0.4060, 0.9179, 0.4344],
#         [0.0000, 0.3209, 0.8686, 0.7201]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.4 methane, 0.4 paraffin, 0.8 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.4 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.6909, 0.8222, 0.0776, 0.8898],
#         [0.7211, 0.4959, 0.1444, 0.2836]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 9
# tensor([[0.4474, 0.9731, 0.8047, 1.0000],
#         [0.0858, 1.0000, 0.9547, 0.6657]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0393, 0.2787, 0.8654, 0.5855],
#         [0.0000, 0.4346, 0.8897, 0.8910]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.3 methane, 0.3 paraffin, 0.8 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.5 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.8130, 0.8487, 0.0075, 0.4738],
#         [0.1962, 0.1335, 0.5749, 0.4220]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 10
# tensor([[0.3127, 1.0000, 1.0000, 0.6677],
#         [0.0000, 1.0000, 0.8059, 0.8623]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0000, 0.1916, 1.0000, 0.7867],
#         [0.0666, 0.3327, 0.8220, 0.5695]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.4 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 0.9 CO conversion, 0.2 methane, 0.3 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0936, 0.9522, 0.4851, 0.2459],
#         [0.7746, 0.7872, 0.9673, 0.1445]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 11
# tensor([[0.0000, 1.0000, 1.0000, 0.4656],
#         [0.3759, 1.0000, 0.9695, 0.7812]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.2023, 0.3196, 0.7824, 0.6808],
#         [0.0000, 0.3314, 0.9047, 0.4949]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.2 methane, 0.3 paraffin, 0.7 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.3 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.9035, 0.1731, 0.1371, 0.7119],
#         [0.4084, 0.1613, 0.0151, 0.8289]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 12
# tensor([[0.4602, 1.0000, 0.9263, 0.6141],
#         [0.2421, 1.0000, 1.0000, 0.8807]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.0000, 0.3130, 0.7638, 0.6747],
#         [0.3632, 0.3204, 0.8305, 0.6675]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.8 CO conversion, 0.2 methane, 0.3 paraffin, 0.7 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.4 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0260, 0.3668, 0.4303, 0.0617],
#         [0.0856, 0.7776, 0.3473, 0.8225]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 13
# tensor([[0.2114, 1.0000, 1.0000, 1.0000],
#         [0.3081, 1.0000, 1.0000, 0.7091]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0000, 1.0000, 0.0000, 1.0000],
#         [0.2914, 0.3211, 0.8171, 0.6676]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.0 CO conversion, -0.0 methane, -0.0 paraffin, 0.0 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.4 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.7349, 0.0837, 0.7197, 0.4009],
#         [0.8665, 0.4842, 0.5486, 0.6956]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 14
# tensor([[0.3457, 0.6798, 0.9170, 0.7812],
#         [0.2177, 1.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step
# tensor([[0.2802, 0.4589, 0.8138, 0.6334],
#         [0.2888, 0.0591, 0.8274, 0.6491]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.3 methane, 0.4 paraffin, 0.7 light olefins. Option B: regime of 0.9 CO conversion, 0.2 methane, 0.4 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step
# tensor([[0.4141, 0.5504, 0.9733, 0.2192],
#         [0.7212, 0.7744, 0.4255, 0.6974]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 15
# tensor([[0.1933, 1.0000, 1.0000, 1.0000],
#         [0.7023, 0.2750, 0.6840, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# tensor([[0.2196, 0.1092, 0.8154, 0.6024],
#         [0.5804, 0.0000, 0.8709, 0.8477]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.2 methane, 0.3 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.5 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# tensor([[0.5716, 0.4598, 0.0276, 0.8858],
#         [0.5382, 0.8467, 0.9513, 0.8967]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 16
# tensor([[0.3299, 1.0000, 1.0000, 1.0000],
#         [0.0000, 1.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# tensor([[0.3958, 0.0000, 0.8426, 0.7523],
#         [1.0000, 0.0000, 0.9128, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.2 methane, 0.4 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.7 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# tensor([[0.7017, 0.7275, 0.8322, 0.1936],
#         [0.5102, 0.6204, 0.7815, 0.7231]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 17
# tensor([[0.0000, 1.0000, 1.0000, 1.0000],
#         [0.3007, 1.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# tensor([[0.8433, 0.0000, 0.8512, 0.9203],
#         [1.0000, 0.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.4 methane, 0.9 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# tensor([[0.4086, 0.9000, 0.9135, 0.4055],
#         [0.8796, 0.5595, 0.4655, 0.7541]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 18
# tensor([[0.0000, 1.0000, 1.0000, 1.0000],
#         [1.0000, 0.0000, 0.7836, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# tensor([[1.0000, 0.0000, 0.8614, 0.7963],
#         [0.6884, 0.0000, 0.8589, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.5 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# tensor([[0.1778, 0.9938, 0.8881, 0.3987],
#         [0.6799, 0.5181, 0.8176, 0.5672]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step
# 19
# tensor([[0.3028, 1.0000, 1.0000, 1.0000],
#         [0.0000, 1.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# tensor([[1.0000, 0.0000, 0.8657, 0.8142],
#         [1.0000, 0.3606, 0.8603, 0.9269]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.4 methane, 0.7 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step
# tensor([[0.6682, 0.9266, 0.6826, 0.1058],
#         [0.1408, 0.4695, 0.6203, 0.3995]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 20
# tensor([[0.0000, 1.0000, 1.0000, 1.0000],
#         [0.3441, 1.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# tensor([[1.0000, 0.0000, 0.8862, 0.7418],
#         [1.0000, 0.0000, 0.8434, 0.9575]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step
# tensor([[0.6175, 0.6375, 0.9237, 0.6566],
#         [0.4355, 0.8691, 0.3477, 0.9871]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffin, 0.1 light olefins. Option B: regime of 0.9 CO conversion, 0.2 methane, 0.3 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffin, 0.1 light olefins. Option B: regime of 0.1 CO conversion, 0.0 methane, 0.0 paraffins, 0.1 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.1 methane, 0.3 paraffin, 0.7 light olefins. Option B: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffins, 0.9 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.2 methane, 0.3 paraffin, 0.8 light olefins. Option B: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffins, 0.9 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.1 methane, 0.3 paraffin, 0.7 light olefins. Option B: regime of 0.9 CO conversion, 0.2 methane, 0.3 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.1 methane, 0.3 paraffin, 0.7 light olefins. Option B: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffins, 0.1 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.2 CO conversion, 0.0 methane, 0.0 paraffin, 0.1 light olefins. Option B: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffins, 0.9 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.1 methane, 0.3 paraffin, 0.7 light olefins. Option B: regime of 0.1 CO conversion, 0.0 methane, 0.0 paraffins, 0.1 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.1 CO conversion, 0.0 methane, 0.0 paraffin, 0.1 light olefins. Option B: regime of 0.9 CO conversion, 0.2 methane, 0.3 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.1 CO conversion, 0.0 methane, 0.0 paraffin, 0.1 light olefins. Option B: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffins, 0.9 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1
# tensor([[0.3487, 1.0000, 1.0000, 0.3499],
#         [0.9084, 0.0960, 0.7315, 0.5961]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.5533, 0.9952, 0.7009, 0.2326],
#         [0.6820, 0.6307, 0.8012, 0.4981]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffin, 0.8 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.4 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.6460, 0.0365, 0.1621, 0.7165],
#         [0.5087, 0.1195, 0.4468, 0.7865]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2
# tensor([[0.3755, 0.9857, 1.0000, 0.5856],
#         [0.2964, 1.0000, 1.0000, 0.1257]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.5769, 0.4215, 0.7988, 0.4651],
#         [0.7727, 0.8654, 0.7905, 0.5388]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.3 methane, 0.4 paraffin, 0.8 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.4 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.5160, 0.5469, 0.0211, 0.9633],
#         [0.3130, 0.8335, 0.6334, 0.5757]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3
# tensor([[0.6516, 0.7668, 1.0000, 0.5598],
#         [0.1737, 1.0000, 0.9878, 0.5663]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.6321, 0.4176, 0.7014, 0.4361],
#         [0.5458, 0.5567, 0.9429, 0.5195]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.2 methane, 0.3 paraffin, 0.7 light olefins. Option B: regime of 0.9 CO conversion, 0.5 methane, 0.5 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.8944, 0.7575, 0.2038, 0.0200],
#         [0.0726, 0.5218, 0.9809, 0.8233]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4
# tensor([[0.2613, 1.0000, 1.0000, 0.4829],
#         [0.0510, 1.0000, 1.0000, 0.8616]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.6555, 0.4191, 0.7613, 0.3454],
#         [0.5619, 0.4732, 0.6811, 0.6065]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.2 methane, 0.3 paraffin, 0.8 light olefins. Option B: regime of 0.9 CO conversion, 0.2 methane, 0.3 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.8039, 0.7101, 0.2827, 0.1183],
#         [0.2645, 0.0408, 0.6446, 0.7717]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 5
# tensor([[0.0000, 1.0000, 1.0000, 0.7328],
#         [0.3413, 1.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.5453, 0.1875, 0.7215, 0.3249],
#         [0.6955, 0.5015, 0.7619, 0.3912]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.8 CO conversion, 0.2 methane, 0.2 paraffin, 0.8 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.3 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.7066, 0.1031, 0.1916, 0.7975],
#         [0.0500, 0.5419, 0.4095, 0.0128]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 6
# tensor([[0.0000, 1.0000, 1.0000, 0.7789],
#         [0.0000, 0.3955, 1.0000, 0.8295]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.7360, 0.4534, 0.9111, 0.4018],
#         [0.5931, 0.6650, 0.5935, 0.4206]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.5 methane, 0.4 paraffin, 0.8 light olefins. Option B: regime of 0.8 CO conversion, 0.1 methane, 0.2 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0270, 0.9813, 0.5484, 0.0773],
#         [0.4965, 0.4385, 0.3112, 0.8223]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 7
# tensor([[0.0000, 0.0000, 1.0000, 1.0000],
#         [0.0000, 1.0000, 1.0000, 0.8128]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.6918, 0.5831, 0.8974, 0.2802],
#         [0.7024, 0.3676, 0.7941, 0.4311]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.5 methane, 0.3 paraffin, 0.8 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.4 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.4573, 0.9574, 0.7246, 0.5534],
#         [0.5715, 0.3399, 0.4435, 0.3419]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 8
# tensor([[0.3050, 0.0000, 0.7974, 0.8638],
#         [0.0000, 1.0000, 1.0000, 0.7126]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0000, 0.0000, 0.0000, 0.0000],
#         [0.6901, 0.5324, 0.8686, 0.3053]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of -0.0 CO conversion, -0.0 methane, -0.0 paraffin, 0.1 light olefins. Option B: regime of 0.9 CO conversion, 0.4 methane, 0.3 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.5982, 0.4719, 0.5020, 0.5972],
#         [0.6444, 0.3837, 0.8293, 0.4382]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 9
# tensor([[0.8413, 0.0000, 0.7844, 0.9248],
#         [0.0000, 0.1744, 0.8331, 0.7927]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.5360, 0.5379, 0.8973, 0.3240],
#         [0.9348, 0.5893, 0.8719, 0.3486]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.5 methane, 0.4 paraffin, 0.8 light olefins. Option B: regime of 0.9 CO conversion, 0.5 methane, 0.4 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.2519, 0.3374, 0.4033, 0.1884],
#         [0.5500, 0.0410, 0.4000, 0.0080]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 10
# tensor([[0.0000, 1.0000, 0.0000, 0.7023],
#         [0.3061, 0.0000, 0.9654, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.4614, 0.5882, 1.0000, 0.2104],
#         [0.6551, 0.5275, 0.8371, 0.3516]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.7 methane, 0.3 paraffin, 0.8 light olefins. Option B: regime of 0.9 CO conversion, 0.4 methane, 0.3 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.2945, 0.6085, 0.8027, 0.2536],
#         [0.4587, 0.8386, 0.7641, 0.4432]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 11
# tensor([[0.3818, 0.0000, 1.0000, 1.0000],
#         [0.0000, 0.0000, 0.3851, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0000, 1.0000, 0.0000, 1.0000],
#         [0.6756, 0.5061, 0.8705, 0.2858]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.0 CO conversion, -0.0 methane, -0.0 paraffin, 0.0 light olefins. Option B: regime of 0.9 CO conversion, 0.4 methane, 0.3 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.4437, 0.6001, 0.5763, 0.6848],
#         [0.0391, 0.2781, 0.9901, 0.8986]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 12
# tensor([[0.3647, 0.0000, 1.0000, 1.0000],
#         [0.0000, 1.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# tensor([[0.6835, 0.4541, 0.8870, 0.4551],
#         [0.6670, 0.5345, 0.8627, 0.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.4 methane, 0.4 paraffin, 0.8 light olefins. Option B: regime of 0.6 CO conversion, 0.5 methane, 0.1 paraffins, 1.0 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.8091, 0.9122, 0.1666, 0.5315],
#         [0.5074, 0.9448, 0.1778, 0.6674]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 13
# tensor([[0.3260, 0.0000, 1.0000, 1.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.6578, 0.5235, 0.8660, 0.3504],
#         [0.0000, 0.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.4 methane, 0.4 paraffin, 0.8 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# tensor([[0.0472, 0.5655, 0.6703, 0.4210],
#         [0.3722, 0.2514, 0.7112, 0.5123]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 14
# tensor([[0.4021, 0.0000, 1.0000, 1.0000],
#         [0.0000, 0.0000, 1.0000, 0.4624]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# tensor([[0.3944, 0.0000, 1.0000, 1.0000],
#         [0.2241, 0.4235, 0.8628, 0.6032]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.4 methane, 0.7 paraffin, 0.7 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.4 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# tensor([[0.6853, 0.4137, 0.9362, 0.6251],
#         [0.9988, 0.5355, 0.6814, 0.4855]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 15
# tensor([[5.2701e-05, 0.0000e+00, 1.0000e+00, 1.0000e+00],
#         [6.7482e-01, 0.0000e+00, 1.0000e+00, 1.0000e+00]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step
# tensor([[0.5996, 0.1332, 0.9954, 0.9786],
#         [0.0000, 0.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.4 methane, 0.8 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# tensor([[0.4994, 0.1682, 0.4992, 0.4097],
#         [0.8228, 0.8685, 0.3231, 0.0892]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 16
# tensor([[0.4334, 0.0000, 1.0000, 1.0000],
#         [1.0000, 0.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step
# tensor([[0.6762, 0.5525, 0.8125, 0.3425],
#         [0.0347, 0.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.3 methane, 0.3 paraffin, 0.8 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# tensor([[0.1770, 0.5699, 0.7910, 0.9397],
#         [0.2290, 0.0481, 0.8161, 0.4203]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 17
# tensor([[1.0000, 0.0000, 0.5464, 1.0000],
#         [1.0000, 0.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# tensor([[0.0660, 0.0000, 1.0000, 1.0000],
#         [0.0000, 0.0000, 1.0000, 0.6351]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 0.9 CO conversion, 0.3 methane, 0.5 paraffins, 0.8 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option A.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# tensor([[0.8861, 0.3324, 0.4709, 0.5910],
#         [0.8801, 0.6507, 0.3323, 0.8335]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 18
# tensor([[1., 0., 1., 1.],
#         [1., 1., 0., 0.]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# tensor([[0.5750, 0.5473, 1.0000, 0.3532],
#         [0.0000, 0.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 0.9 CO conversion, 0.6 methane, 0.4 paraffin, 0.8 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# tensor([[0.3339, 0.6623, 0.1501, 0.2888],
#         [0.5866, 0.9023, 0.0832, 0.4694]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 19
# tensor([[0.5134, 0.0000, 1.0000, 1.0000],
#         [1.0000, 0.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# tensor([[0.0000, 0.4286, 1.0000, 1.0000],
#         [0.0000, 0.0000, 1.0000, 1.0000]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.4 methane, 0.6 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step
# tensor([[6.2353e-04, 7.2396e-01, 9.3522e-01, 5.0439e-01],
#         [5.8722e-02, 5.6778e-01, 2.5214e-01, 9.3352e-02]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 20
# tensor([[1., 0., 1., 1.],
#         [0., 0., 0., 0.]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# tensor([[1., 0., 1., 1.],
#         [0., 0., 1., 1.]])
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Suppose you're managing a Fischer-Tropsch synthesis process. We only want to maximize the CO conversion. Option A: regime of 1.0 CO conversion, 0.4 methane, 0.9 paraffin, 0.7 light olefins. Option B: regime of 1.0 CO conversion, 0.3 methane, 0.6 paraffins, 0.7 light olefins. Choose only one option, only answer with 'Option A' or 'Option B'
# Option B.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# tensor([[0.6692, 0.1611, 0.1524, 0.8145],
#         [0.3054, 0.5076, 0.0312, 0.9414]], dtype=torch.float64)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step

# %%
with open('best_vals_case_2.pkl', 'wb') as handle:
    pickle.dump(best_vals, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('best_vals_case_2.pkl', 'rb') as handle:
    loaded_data = pickle.load(handle)

# %%
loaded_data
# Out:
# {'EUBO': [[0.832346498966217,
#    0.8698467016220093,
#    0.9543025493621826,
#    0.9547447562217712,
#    0.9604210257530212,
#    0.9964376091957092,
#    0.9964376091957092,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613,
#    0.9977957606315613],
#   [0.6748826503753662,
#    0.7508968114852905,
#    0.8107439279556274,
#    0.8107439279556274,
#    0.9171929955482483,
#    0.9171929955482483,
#    0.9684693813323975,
#    0.9859500527381897,
#    0.9869920611381531,
#    0.9869920611381531,
#    0.9869920611381531,
#    0.9869920611381531,
#    0.9869920611381531,
#    0.9869920611381531,
#    0.9869920611381531,
#    0.9869920611381531,
#    0.9882803559303284,
#    0.9882803559303284,
#    0.9882805943489075,
#    0.9882805943489075,
#    0.9890061020851135],
#   [0.8805213570594788,
#    0.8991538882255554,
#    0.9268748760223389,
#    0.946047842502594,
#    0.946047842502594,
#    0.988862931728363,
#    0.988862931728363,
#    0.988862931728363,
#    0.988862931728363,
#    0.988862931728363,
#    0.988862931728363,
#    0.988862931728363,
#    0.988862931728363,
#    0.988862931728363,
#    0.988862931728363,
#    0.9923763871192932,
#    0.9986152052879333,
#    0.9986152052879333,
#    0.9986152052879333,
#    0.9986152052879333,
#    0.9986152052879333]],
#  'EUBO-LLM': [[0.832346498966217,
#    0.8698535561561584,
#    0.9543043971061707,
#    0.9547305703163147,
#    0.9916675686836243,
#    1.0058573484420776,
#    1.0058573484420776,
#    1.0177124738693237,
#    1.0177122354507446,
#    1.0177122354507446,
#    1.0177124738693237,
#    1.0177124738693237,
#    1.0177124738693237,
#    1.0177124738693237,
#    1.0177124738693237,
#    1.0177124738693237,
#    1.0177124738693237,
#    1.0177124738693237,
#    1.0177124738693237,
#    1.0177124738693237,
#    1.0177124738693237],
#   [0.6748826503753662,
#    0.7294380068778992,
#    0.7395060062408447,
#    0.7559440732002258,
#    0.8475069403648376,
#    0.8475069403648376,
#    0.8475069403648376,
#    0.9089829921722412,
#    0.9089831113815308,
#    0.9384850859642029,
#    0.9384850859642029,
#    0.9384850859642029,
#    0.9384850859642029,
#    0.9384850859642029,
#    0.9384850859642029,
#    0.9580431580543518,
#    1.0053973197937012,
#    1.0053973197937012,
#    1.0053973197937012,
#    1.0053973197937012,
#    1.0053973197937012],
#   [0.8805213570594788,
#    0.9143669605255127,
#    0.9214092493057251,
#    0.9328365921974182,
#    0.9328367114067078,
#    0.9328367114067078,
#    0.9328365921974182,
#    0.9328365921974182,
#    0.9328365921974182,
#    0.9328365921974182,
#    0.9328365921974182,
#    0.9328365921974182,
#    0.9328365921974182,
#    0.9537888169288635,
#    0.9810746312141418,
#    0.9917768836021423,
#    0.9917768836021423,
#    0.9917768836021423,
#    0.9917768836021423,
#    0.9917768836021423,
#    0.9986150860786438]],
#  'rand': [[0.832346498966217,
#    0.9507758617401123,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099,
#    0.9785594344139099],
#   [0.6748826503753662,
#    0.6748826503753662,
#    0.6748826503753662,
#    0.6748826503753662,
#    0.6748826503753662,
#    0.9180103540420532,
#    0.9201294779777527,
#    0.9201294779777527,
#    0.9201294779777527,
#    0.9201294779777527,
#    0.9201294779777527,
#    0.9201294779777527,
#    0.9201294779777527,
#    0.9201294779777527,
#    0.9201294779777527,
#    0.9851248860359192,
#    0.9851248860359192,
#    0.9851248860359192,
#    0.9851248860359192,
#    0.9851248860359192,
#    0.9851248860359192],
#   [0.8805213570594788,
#    0.8805213570594788,
#    0.8805213570594788,
#    0.9431450366973877,
#    0.9431450366973877,
#    0.9431450366973877,
#    0.9431450366973877,
#    0.9431450366973877,
#    0.9431450366973877,
#    0.9431450366973877,
#    0.9431450366973877,
#    0.9490667581558228,
#    0.9490667581558228,
#    0.9490667581558228,
#    0.9499526023864746,
#    0.9499526023864746,
#    0.9499526023864746,
#    0.9499526023864746,
#    0.9499526023864746,
#    0.9499526023864746,
#    0.9499526023864746]]}

# %%
from matplotlib import pyplot as plt


# %matplotlib inline

plt.rcParams.update({"font.size": 14})

algo_labels = {
    "rand": "Random Exploration",
    "EUBO-LLM": "EUBO-LLM",
    "EUBO": "EUBO", 
}


def ci(y):
    return 1.96 * y.std(axis=0) / np.sqrt(y.shape[0])


# the utility function is maximized at the full vector of 1
#optimal_val = utility(torch.tensor([[1] * dim])).item()
iters = list(range(NUM_BATCHES + 1))

fig, ax = plt.subplots(1, 1, figsize=(8, 6))
# plot the optimal value
#ax.plot(
#    iters,
#    [optimal_val] * len(iters),
#    label="Optimal Function Value",
#    color="black",
##    linewidth=1.5,
#)

# plot the the best observed value from each algorithm
for algo in algos:
    ys = np.vstack(best_vals[algo])
    ax.errorbar(
        iters, ys.mean(axis=0), yerr=ci(ys), label=algo_labels[algo], linewidth=1.5
    )

ax.set(
    #xlabel=f"Number of queries q = {q_eubo}, num_initial_comp = {q_comp}, num_initial_samp = {q_data})",
    ylabel="Best observed value\nas evaluated in the synthetic utility function",
    title=f"Obj 2: only maximising CO conversion",
)

ax.set_xticks(np.arange(0, NUM_BATCHES + 1, 1))

ax.set_xlabel(f"Number of queries q = {q_eubo}, num_initial_comp = {q_comp}, num_initial_samp = {q_data})", fontsize=10)  # Reducing the font size
ax.legend(loc="best")
plt.savefig("comparison_first_case_2_corrected.png",bbox_inches="tight", dpi=400)
